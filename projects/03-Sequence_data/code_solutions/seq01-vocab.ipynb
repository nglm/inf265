# %%
import torch
from os import listdir
import re
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# %%
# tokenizer will split a long text into a list of english words
tokenizer = get_tokenizer('basic_english')

def read_files(datapath='../data_train/'):
    """
    Return a list of strings, one for each line in each .txt files in 'datapath'
    """
    # Find all txt files in directory 
    files = listdir(datapath)
    files = [datapath + f for f in files if f.endswith(".txt")]
    
    # Stores each line of each book in a list
    lines = []
    for f_name in files:
        with open(f_name) as f:
            book = [line.strip() for line in f.readlines()]
        lines += book
    return lines

# Match any word containing digit
no_digits = '\w*[0-9]+\w*'
# Match word containing a uppercase 
no_names = '\w*[A-Z]+\w*'
# Match any sequence containing more than one space
no_spaces = '\s+'

books_train = read_files('../data_train/')
books_val = read_files('../data_val/')
books_test = read_files('../data_test/')

def tokenize(lines):
    """
    Tokenize the list of lines
    """
    list_text = []
    for line in lines:
        list_text += tokenizer(line)
    return list_text

def yield_tokens(lines):
    """
    Yield tokens, ignoring names and digits to build vocabulary
    """
    for line in lines:
        line = re.sub(no_digits, ' ', line)
        line = re.sub(no_names, ' ', line)
        line = re.sub(no_spaces, ' ', line)
        yield tokenizer(line)

def count_freqs(data, vocab):
    """
    Count occurrences of each word in vocabulary in the data
    """
    freqs = torch.zeros(len(vocab), dtype=torch.int)
    for w in data:
        freqs[vocab[w]] += 1
    return freqs

# List of words contained in the dataset
list_words_train = tokenize(books_train)
list_words_val = tokenize(books_val)
list_words_test = tokenize(books_test)

# vocab contains the vocabulary found in the data, associating an index to each word
vocab = build_vocab_from_iterator(yield_tokens(books_train), min_freq=100, specials=["<unk>"])
# vocab.append_token("i")

# Value of default index. This index will be returned when OOV (Out Of Vocabulary) token is queried.
vocab.set_default_index(vocab["<unk>"])
vocab_size = len(vocab)

print("Total number of words in the training dataset:     ", len(list_words_train))
print("Total number of words in the validation dataset:   ", len(list_words_val))
print("Number of distinct words in the training dataset:  ", len(set(list_words_train)))
print("Number of distinct words kept (vocabulary size):   ", vocab_size)

freqs = count_freqs(list_words_train, vocab)
print(freqs.sum())
n_words_train = len(list_words_train)
weights = ((n_words_train - freqs) / n_words_train).to(torch.float)
# Out:
# Total number of words in the dataset:    2684706
# Total number of words in the dataset:    49526
# Number of distinct words in the dataset: 52105
# Number of distinct words kept:           1879
# tensor(2684706)

# %%
generated_path = '../generated/'
torch.save(list_words_train, generated_path + 'books_train.pt')
torch.save(list_words_val,   generated_path + 'books_val.pt')
torch.save(list_words_test,  generated_path + 'books_test.pt')

torch.save(vocab,   generated_path + 'vocab.pt')
torch.save(weights, generated_path + "weight.pt")

# %%
print(freqs[:vocab_size],[vocab.lookup_tokens(range(vocab_size))] )
# Out:
# tensor([456903, 182537, 151278,  ...,    100,    182,    100],
#        dtype=torch.int32) [['<unk>', ',', 'the', '.', 'and', 'of', 'to', 'a', 'in', 'that', 'he', 'was', 'his', 'it', 'with', 'had', 'is', 'not', 'as', 'on', 'him', 'for', 'at', 'you', 'be', 'her', 's', 'which', '!', 'all', '?', 'have', 'from', 'but', 'this', 'by', 'they', 'said', 'are', 'she', 'one', 'were', 'who', 'so', 'there', 'or', 'me', 'them', 'an', 'my', 'will', 'man', 'we', 'up', 'their', 'out', 'been', 'when', 'no', 'would', 'what', 'into', 'if', 'more', 'very', 'could', 'did', 'men', 'has', 'do', 'then', 'some', 'king', 'other', 'time', 'about', 'should', 'went', 'himself', 'came', 'now', 'only', 'your', 'like', 'two', 'little', 'before', 'over', 'made', 'than', 'see', 'may', 'down', 'old', 'us', 'know', 'can', 'good', 'where', 't', '(', ')', 'must', 'great', 'our', 'people', 'go', 'again', 'come', 'its', 'these', 'after', 'any', 'without', 'day', 'upon', 'eyes', '—', 'first', 'way', 'back', 'away', 'am', 'same', 'those', 'thought', 'well', 'say', 'took', 'such', 'long', 'much', 'hand', 'still', 'face', 'how', 'through', 'here', 'head', '-', 'nothing', 'many', 'shall', 'even', 'off', 'just', 'own', 'left', 'saw', 'life', 'house', 'also', 'room', 'heard', 'too', 'being', 'make', 'never', 'take', 'once', 'night', 'each', 'most', 'door', 'seemed', 'under', 'place', 'last', 'right', 'another', 'whole', 'asked', 'began', 'every', 'something', 'called', 'young', 'moment', 'against', 'looked', 'get', 'things', 'might', 'think', 'three', 'told', 'felt', 'father', 'found', 'always', 'got', 'set', 'put', 'let', 'side', 'gave', 'seen', 'round', 'turned', 'give', 'whom', 'country', 'look', 'though', 'both', 'while', 'between', 'going', 'done', 'tell', 'woman', 'because', 'having', 'taken', 'army', 'yet', 'says', 'light', 'knew', 'soon', 'plants', 'few', 'part', 'son', 'others', 'years', 'voice', 'hands', 'love', 'large', 'morning', 'end', 'themselves', 'quite', 'words', 'stood', 'behind', 'thing', 'replied', 'battle', 'white', 'along', 'far', 'together', 'water', 'feet', 'ground', 'brought', 'home', 'anything', 'small', 'everything', 'don', 'mind', 'longer', 'name', 'already', 'does', 'find', 'wife', 'fell', 'word', 'order', 'death', 'matter', 'mother', 'passed', 'herself', 'open', 'near', 'lay', 'll', 'child', 'sat', 'best', 'land', 'work', 'remained', 'bed', 'among', 'better', 'heart', 'alone', 'evening', 'dear', 'full', 'de', 'days', 'air', 'sent', 'poor', 'friend', 'new', 'front', 'since', 'sort', 'four', 'want', 'almost', 'given', 'table', 'became', 'dead', 'held', 'cannot', 'fire', 'ran', 'ever', 'nor', 'myself', 'towards', 'black', 'case', 'thou', 'cried', 'understand', 'looking', 'fall', 'suddenly', 'become', 'answered', 'ready', 'until', 'returned', 'leave', 'winter', 'gone', 'world', 'cut', 'used', 'general', 'often', 'daughter', 'power', 'soul', 'why', 'entered', 'however', 'itself', 'possible', 'war', 'coming', 'arms', 'smile', 'true', 'window', 'half', 'whose', 'saying', 'point', 'less', 'rather', 'enough', 'laid', 'speak', 'certain', 'earth', 'earl', 'fact', 'received', 'hour', 'red', 'garden', 'above', 'ships', 'hundred', 'opened', 'spoke', 'girl', 'lost', 'continued', 'ship', 'trees', 'horse', 'around', 'money', 'body', 'brother', 'hear', 'keep', 'spring', 'town', 'second', 'use', 'hair', 'rest', 'cold', 'terrible', 'close', 'course', 'high', 'husband', 'added', 'killed', 'met', 'road', 'sometimes', 'sound', 'children', 'within', 'whether', 'help', 'followed', 'making', 'thus', 'year', 'five', 'flowers', 'kept', 'o', 'taking', 'turn', 'present', 've', 'yourself', 'early', 'next', 'times', 'dark', 'force', 'necessary', 'officer', 'able', 'sleep', 'till', 'happened', 'either', 'short', 'wish', 'placed', 'street', 'fear', 'known', 'need', 'rose', 'wanted', 'fine', 'letter', 'ask', 'count', 'happy', 'question', 'wall', 'idea', 'care', 'feeling', 'soldiers', 'clock', 'past', 'appeared', 'blood', 'beside', 'talk', 'carried', 'raised', 'later', 'during', 'following', 'soil', 'hold', 'evidently', 'peace', 'corner', 'lat ...

# %%
print([w.item() for w in weights])
print(sum([1-w.item() for w in weights]))
# Out:
# [0.8298126459121704, 0.9320085644721985, 0.9436519145965576, 0.9539141058921814, 0.9693489670753479, 0.9755425453186035, 0.9766220450401306, 0.9816628098487854, 0.9845506548881531, 0.9884337186813354, 0.9861560463905334, 0.9891809225082397, 0.9901263117790222, 0.9901836514472961, 0.9922293424606323, 0.9924911856651306, 0.9925634264945984, 0.9941550493240356, 0.9938194155693054, 0.9941502213478088, 0.994612455368042, 0.9942947030067444, 0.9941006302833557, 0.9940581917762756, 0.9950627684593201, 0.9952702522277832, 0.9952329993247986, 0.9955585598945618, 0.9956017732620239, 0.9956271052360535, 0.9961493015289307, 0.996198832988739, 0.9961243271827698, 0.9950642585754395, 0.9957298636436462, 0.9964841604232788, 0.9957179427146912, 0.9967232942581177, 0.9967221617698669, 0.9958822131156921, 0.9964476823806763, 0.9969385862350464, 0.9968100786209106, 0.9968916773796082, 0.9964953064918518, 0.9973658323287964, 0.9975509643554688, 0.9975870847702026, 0.9976053237915039, 0.997441828250885, 0.9978213906288147, 0.9978798627853394, 0.9972119927406311, 0.9978988170623779, 0.9978511333465576, 0.997947633266449, 0.9979714751243591, 0.9971550107002258, 0.9975356459617615, 0.9980764985084534, 0.9972518682479858, 0.998270571231842, 0.997870922088623, 0.9984143376350403, 0.9984702467918396, 0.9985264539718628, 0.9985171556472778, 0.9985719323158264, 0.9985782504081726, 0.9984240531921387, 0.9976790547370911, 0.9984709620475769, 0.9973784685134888, 0.998629629611969, 0.9986646771430969, 0.9986527562141418, 0.9986728429794312, 0.9987037777900696, 0.9987119436264038, 0.9987406730651855, 0.9983588457107544, 0.9986534714698792, 0.9986773133277893, 0.9987685680389404, 0.9987313151359558, 0.998776376247406, 0.9988106489181519, 0.9988791942596436, 0.9988918900489807, 0.9989023208618164, 0.9988784790039062, 0.9988483190536499, 0.998940646648407, 0.9989358186721802, 0.9989764094352722, 0.9989935755729675, 0.9989455342292786, 0.9989071488380432, 0.9988564848899841, 0.9989901781082153, 0.9990300536155701, 0.9990300536155701, 0.9990296959877014, 0.9989898204803467, 0.9989778995513916, 0.9990140199661255, 0.9989771842956543, 0.9990240931510925, 0.9989503622055054, 0.999078094959259, 0.9989209175109863, 0.998875081539154, 0.9991287589073181, 0.9991105198860168, 0.9991481304168701, 0.9991429448127747, 0.9991623163223267, 0.9996063113212585, 0.9991391897201538, 0.9991716146469116, 0.9991787075996399, 0.9991913437843323, 0.9991921186447144, 0.9992021322250366, 0.999151885509491, 0.9992084503173828, 0.9988840222358704, 0.99920254945755, 0.9992144107818604, 0.9991633892059326, 0.9992066025733948, 0.9992378950119019, 0.9992625117301941, 0.9992352724075317, 0.9992833733558655, 0.9989913105964661, 0.999261736869812, 0.9991164803504944, 0.9992908239364624, 0.9998748302459717, 0.9992073774337769, 0.9992401599884033, 0.9992855787277222, 0.9992620944976807, 0.9993090629577637, 0.999232292175293, 0.9993466734886169, 0.9993473887443542, 0.9993526339530945, 0.9993410706520081, 0.9993559718132019, 0.9993731379508972, 0.9993786811828613, 0.9993850588798523, 0.9993749856948853, 0.9993749856948853, 0.9993645548820496, 0.9993347525596619, 0.9993343949317932, 0.9993563294410706, 0.9993910193443298, 0.9993548393249512, 0.9993902444839478, 0.9994163513183594, 0.9994163513183594, 0.9993910193443298, 0.9993984699249268, 0.9994107484817505, 0.9994252920150757, 0.9993757009506226, 0.999443531036377, 0.9994502067565918, 0.999455451965332, 0.999396562576294, 0.9994397759437561, 0.9994643926620483, 0.9994513392448425, 0.9994729161262512, 0.9994677305221558, 0.9994814991950989, 0.9994599223136902, 0.999464750289917, 0.999482274055481, 0.9994736909866333, 0.9994550347328186, 0.9994915723800659, 0.9994937777519226, 0.9993962049484253, 0.999501645565033, 0.9994945526123047, 0.9995191097259521, 0.9995116591453552, 0.9995131492614746, 0.9993146657943726, 0.9995288252830505, 0.9995374083518982, 0.9995433688163757, 0.9995429515838623, 0.9995504021644592, 0.9995172619819641, 0.9995470643043518, 0 ...
# 0.9999996423721313

# %%
print(vocab)
# Out:
# Vocab()
